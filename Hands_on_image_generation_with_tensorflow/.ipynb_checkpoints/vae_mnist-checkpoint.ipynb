# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import Layer, Input, Conv2D, Dense, Flatten, Reshape, Lambda, Dropout
from tensorflow.keras.layers import Conv2DTranspose, MaxPooling2D, UpSampling2D, LeakyReLU, BatchNormalization
from tensorflow.keras.activations import relu
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import tensorflow_datasets as tfds

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
(ds_train, ds_test_), ds_info = tfds.load('mnist',
                                          split=['train', 'test'],
                                          shuffle_files=True,
                                          as_supervised=True,
                                          with_info=True)

# %%
batch_size = 256

# %%
def preprocess(image, label):
    image = tf.cast(image, tf.float32)
    image = image/255.
    return image, image

# %%
ds_train =  ds_train.map(preprocess).cache().shuffle(ds_info.splits['train'].num_examples).batch(batch_size)
ds_test = ds_test_.map(preprocess).batch(batch_size).cache().prefetch(batch_size)

# %%
# return label for testing

def preprocess_with_label(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.math.round(image/255.)
    return image, label

# %%
ds_test_label = ds_test_.map(preprocess_with_label).batch(1000)

# %%
class GaussianSampling(Layer):
    def call(self, inputs):
        means, logvar = inputs
        epsilon = tf.random.normal(shape=tf.shape(means), mean=0, stddev=1.)
        samples = means + tf.exp(0.5*logvar)*epsilon
        
        return samples

# %%
class Encoder(Layer):
    def __init__(self, z_dim, name='encoder'):
        super(Encoder, self).__init__(name=name)
        
        self.features_extract = Sequential([
            Conv2D(filters=8, kernel_size=(8,8), strides=2, padding='same', activation='relu'),
            Conv2D(filters=8, kernel_size=(8,8), strides=1, padding='same', activation='relu'),
            Conv2D(filters=8, kernel_size=(8,8), strides=2, padding='same', activation='relu'),
            Conv2D(filters=8, kernel_size=(8,8), strides=1, padding='same', activation='relu'),
            Flatten()])
        
        self.dense_mean = Dense(z_dim, name='mean')
        self.dense_logvar = Dense(z_dim, name='logvar')
        self.sampler = GaussianSampling()
        
    def call(self, inputs):
        x = self.features_extract(inputs)
        mean = self.dense_mean(x)
        logvar = self.dense_logvar(x)
        z = self.sampler([mean, logvar])
        return z, mean, logvar

# %%
class Decoder(Layer):
    def __init__(self, z_dim, name='decoder'):
        super(Decoder, self).__init__(name=name)
        
        self.forward = Sequential([
            Dense(7*7*64, activation='relu'),
            Reshape((7,7,64)),
            Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same', activation='relu'),
            UpSampling2D((2,2)),
            Conv2D(filters=32, kernel_size=(3,3), strides=1, padding='same', activation='relu'),
            UpSampling2D((2,2)),
            Conv2D(filters=1, kernel_size=(3,3), strides=1, padding='same', activation='sigmoid')])
    def call(self, inputs):
        return self.forward(inputs)

# %%
class VAE(Model):
    def __init__(self, z_dim, name='vae'):
        super(VAE, self).__init__(name=name)
        self.encoder = Encoder(z_dim)
        self.decoder = Decoder(z_dim)
        self.mean = None
        self.logvar = None
        
    def call(self, inputs):
        z, self.mean, self.logvar = self.encoder(inputs)
        out = self.decoder(z)
        return out

# %%
vae = VAE(z_dim=2)

# %%
def vae_kl_loss(y_true, y_pred):
    kl_loss = -0.5 * tf.reduce_mean(1 + vae.logvar - tf.square(vae.mean) - tf.exp(vae.logvar))
    return kl_loss

# %%
def vae_rc_loss(y_true, y_pred):
    rc_loss = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    return rc_loss

# %%
def vae_loss(y_true, y_pred):
    kl_loss = vae_kl_loss(y_true, y_pred)
    rc_loss = vae_rc_loss(y_true, y_pred)
    kl_weight_const = 1e-2
    return kl_weight_const*kl_loss + rc_loss

# %%
model_path = 'vae.h5'

# %%
checkpoint = ModelCheckpoint(model_path,
                             monitor='vae_rc_loss',
                             verbose=1,
                             save_best_only=True,
                             mode='auto',
                             save_weights_only=True)
early = EarlyStopping(monitor='vae_rc_loss',
                      mode='auto',
                      patience=5)
callbacks_list = [checkpoint, early]

# %%
vae.compile(
    loss = [vae_loss],
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3),
    metrics=[vae_kl_loss, vae_rc_loss])

# %%
vae.fit(ds_train, validation_data=ds_test,
        epochs=50, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 235/235 [==============================] - ETA: 0s - loss: 0.2803 - vae_kl_loss: 0.6415 - vae_rc_loss: 0.2739
# Epoch 1: vae_rc_loss improved from inf to 0.27388, saving model to vae.h5
# 235/235 [==============================] - 14s 14ms/step - loss: 0.2803 - vae_kl_loss: 0.6415 - vae_rc_loss: 0.2739 - val_loss: 0.2348 - val_vae_kl_loss: 1.3183 - val_vae_rc_loss: 0.2216
# Epoch 2/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.2297 - vae_kl_loss: 1.5082 - vae_rc_loss: 0.2146
# Epoch 2: vae_rc_loss improved from 0.27388 to 0.21460, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2297 - vae_kl_loss: 1.5082 - vae_rc_loss: 0.2146 - val_loss: 0.2257 - val_vae_kl_loss: 1.5501 - val_vae_rc_loss: 0.2102
# Epoch 3/50
# 229/235 [============================>.] - ETA: 0s - loss: 0.2241 - vae_kl_loss: 1.6804 - vae_rc_loss: 0.2073
# Epoch 3: vae_rc_loss improved from 0.21460 to 0.20717, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2240 - vae_kl_loss: 1.6818 - vae_rc_loss: 0.2072 - val_loss: 0.2207 - val_vae_kl_loss: 1.7933 - val_vae_rc_loss: 0.2028
# Epoch 4/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.2203 - vae_kl_loss: 1.8097 - vae_rc_loss: 0.2022
# Epoch 4: vae_rc_loss improved from 0.20717 to 0.20219, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2203 - vae_kl_loss: 1.8101 - vae_rc_loss: 0.2022 - val_loss: 0.2180 - val_vae_kl_loss: 1.7989 - val_vae_rc_loss: 0.2000
# Epoch 5/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2174 - vae_kl_loss: 1.9073 - vae_rc_loss: 0.1984
# Epoch 5: vae_rc_loss improved from 0.20219 to 0.19840, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2175 - vae_kl_loss: 1.9078 - vae_rc_loss: 0.1984 - val_loss: 0.2153 - val_vae_kl_loss: 1.9595 - val_vae_rc_loss: 0.1957
# Epoch 6/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2155 - vae_kl_loss: 1.9772 - vae_rc_loss: 0.1957
# Epoch 6: vae_rc_loss improved from 0.19840 to 0.19570, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2155 - vae_kl_loss: 1.9780 - vae_rc_loss: 0.1957 - val_loss: 0.2134 - val_vae_kl_loss: 2.0326 - val_vae_rc_loss: 0.1931
# Epoch 7/50
# 233/235 [============================>.] - ETA: 0s - loss: 0.2138 - vae_kl_loss: 2.0245 - vae_rc_loss: 0.1936
# Epoch 7: vae_rc_loss improved from 0.19570 to 0.19359, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2138 - vae_kl_loss: 2.0246 - vae_rc_loss: 0.1936 - val_loss: 0.2131 - val_vae_kl_loss: 1.9506 - val_vae_rc_loss: 0.1936
# Epoch 8/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2125 - vae_kl_loss: 2.0567 - vae_rc_loss: 0.1920
# Epoch 8: vae_rc_loss improved from 0.19359 to 0.19198, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2125 - vae_kl_loss: 2.0560 - vae_rc_loss: 0.1920 - val_loss: 0.2118 - val_vae_kl_loss: 2.0490 - val_vae_rc_loss: 0.1913
# Epoch 9/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2118 - vae_kl_loss: 2.0962 - vae_rc_loss: 0.1908
# Epoch 9: vae_rc_loss improved from 0.19198 to 0.19079, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2118 - vae_kl_loss: 2.0972 - vae_rc_loss: 0.1908 - val_loss: 0.2108 - val_vae_kl_loss: 2.0487 - val_vae_rc_loss: 0.1903
# Epoch 10/50
# 233/235 [============================>.] - ETA: 0s - loss: 0.2109 - vae_kl_loss: 2.1223 - vae_rc_loss: 0.1897
# Epoch 10: vae_rc_loss improved from 0.19079 to 0.18967, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2109 - vae_kl_loss: 2.1224 - vae_rc_loss: 0.1897 - val_loss: 0.2115 - val_vae_kl_loss: 2.1233 - val_vae_rc_loss: 0.1902
# Epoch 11/50
# 229/235 [============================>.] - ETA: 0s - loss: 0.2102 - vae_kl_loss: 2.1387 - vae_rc_loss: 0.1888
# Epoch 11: vae_rc_loss improved from 0.18967 to 0.18881, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2102 - vae_kl_loss: 2.1381 - vae_rc_loss: 0.1888 - val_loss: 0.2095 - val_vae_kl_loss: 2.1262 - val_vae_rc_loss: 0.1882
# Epoch 12/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.2096 - vae_kl_loss: 2.1596 - vae_rc_loss: 0.1880
# Epoch 12: vae_rc_loss improved from 0.18881 to 0.18799, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2096 - vae_kl_loss: 2.1598 - vae_rc_loss: 0.1880 - val_loss: 0.2097 - val_vae_kl_loss: 2.2448 - val_vae_rc_loss: 0.1872
# Epoch 13/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2090 - vae_kl_loss: 2.1720 - vae_rc_loss: 0.1873
# Epoch 13: vae_rc_loss improved from 0.18799 to 0.18734, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2091 - vae_kl_loss: 2.1717 - vae_rc_loss: 0.1873 - val_loss: 0.2084 - val_vae_kl_loss: 2.1941 - val_vae_rc_loss: 0.1865
# Epoch 14/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.2088 - vae_kl_loss: 2.1879 - vae_rc_loss: 0.1869
# Epoch 14: vae_rc_loss improved from 0.18734 to 0.18690, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2088 - vae_kl_loss: 2.1877 - vae_rc_loss: 0.1869 - val_loss: 0.2088 - val_vae_kl_loss: 2.2319 - val_vae_rc_loss: 0.1864
# Epoch 15/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2084 - vae_kl_loss: 2.1984 - vae_rc_loss: 0.1864
# Epoch 15: vae_rc_loss improved from 0.18690 to 0.18638, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2084 - vae_kl_loss: 2.1989 - vae_rc_loss: 0.1864 - val_loss: 0.2082 - val_vae_kl_loss: 2.2154 - val_vae_rc_loss: 0.1860
# Epoch 16/50
# 233/235 [============================>.] - ETA: 0s - loss: 0.2078 - vae_kl_loss: 2.2151 - vae_rc_loss: 0.1857
# Epoch 16: vae_rc_loss improved from 0.18638 to 0.18569, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2078 - vae_kl_loss: 2.2150 - vae_rc_loss: 0.1857 - val_loss: 0.2075 - val_vae_kl_loss: 2.1512 - val_vae_rc_loss: 0.1860
# Epoch 17/50
# 233/235 [============================>.] - ETA: 0s - loss: 0.2075 - vae_kl_loss: 2.2213 - vae_rc_loss: 0.1853
# Epoch 17: vae_rc_loss improved from 0.18569 to 0.18529, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2075 - vae_kl_loss: 2.2217 - vae_rc_loss: 0.1853 - val_loss: 0.2067 - val_vae_kl_loss: 2.2694 - val_vae_rc_loss: 0.1840
# Epoch 18/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2072 - vae_kl_loss: 2.2326 - vae_rc_loss: 0.1848
# Epoch 18: vae_rc_loss improved from 0.18529 to 0.18485, saving model to vae.h5
# 235/235 [==============================] - 3s 10ms/step - loss: 0.2072 - vae_kl_loss: 2.2325 - vae_rc_loss: 0.1849 - val_loss: 0.2071 - val_vae_kl_loss: 2.2013 - val_vae_rc_loss: 0.1850
# Epoch 19/50
# 233/235 [============================>.] - ETA: 0s - loss: 0.2071 - vae_kl_loss: 2.2459 - vae_rc_loss: 0.1847
# Epoch 19: vae_rc_loss improved from 0.18485 to 0.18466, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2071 - vae_kl_loss: 2.2455 - vae_rc_loss: 0.1847 - val_loss: 0.2065 - val_vae_kl_loss: 2.2429 - val_vae_rc_loss: 0.1841
# Epoch 20/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2067 - vae_kl_loss: 2.2438 - vae_rc_loss: 0.1843
# Epoch 20: vae_rc_loss improved from 0.18466 to 0.18424, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2067 - vae_kl_loss: 2.2435 - vae_rc_loss: 0.1842 - val_loss: 0.2067 - val_vae_kl_loss: 2.2550 - val_vae_rc_loss: 0.1841
# Epoch 21/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.2064 - vae_kl_loss: 2.2635 - vae_rc_loss: 0.1838
# Epoch 21: vae_rc_loss improved from 0.18424 to 0.18378, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2064 - vae_kl_loss: 2.2635 - vae_rc_loss: 0.1838 - val_loss: 0.2064 - val_vae_kl_loss: 2.2467 - val_vae_rc_loss: 0.1839
# Epoch 22/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2063 - vae_kl_loss: 2.2651 - vae_rc_loss: 0.1837
# Epoch 22: vae_rc_loss improved from 0.18378 to 0.18363, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2063 - vae_kl_loss: 2.2663 - vae_rc_loss: 0.1836 - val_loss: 0.2058 - val_vae_kl_loss: 2.3228 - val_vae_rc_loss: 0.1826
# Epoch 23/50
# 229/235 [============================>.] - ETA: 0s - loss: 0.2061 - vae_kl_loss: 2.2724 - vae_rc_loss: 0.1834
# Epoch 23: vae_rc_loss improved from 0.18363 to 0.18334, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2061 - vae_kl_loss: 2.2717 - vae_rc_loss: 0.1833 - val_loss: 0.2077 - val_vae_kl_loss: 2.3066 - val_vae_rc_loss: 0.1846
# Epoch 24/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2057 - vae_kl_loss: 2.2809 - vae_rc_loss: 0.1829
# Epoch 24: vae_rc_loss improved from 0.18334 to 0.18292, saving model to vae.h5
# 235/235 [==============================] - 2s 11ms/step - loss: 0.2057 - vae_kl_loss: 2.2806 - vae_rc_loss: 0.1829 - val_loss: 0.2058 - val_vae_kl_loss: 2.3074 - val_vae_rc_loss: 0.1827
# Epoch 25/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2056 - vae_kl_loss: 2.2814 - vae_rc_loss: 0.1828
# Epoch 25: vae_rc_loss improved from 0.18292 to 0.18279, saving model to vae.h5
# 235/235 [==============================] - 2s 10ms/step - loss: 0.2056 - vae_kl_loss: 2.2814 - vae_rc_loss: 0.1828 - val_loss: 0.2057 - val_vae_kl_loss: 2.1841 - val_vae_rc_loss: 0.1839
# Epoch 26/50
# 235/235 [==============================] - ETA: 0s - loss: 0.2054 - vae_kl_loss: 2.2840 - vae_rc_loss: 0.1825
# Epoch 26: vae_rc_loss improved from 0.18279 to 0.18254, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2054 - vae_kl_loss: 2.2840 - vae_rc_loss: 0.1825 - val_loss: 0.2060 - val_vae_kl_loss: 2.3592 - val_vae_rc_loss: 0.1824
# Epoch 27/50
# 235/235 [==============================] - ETA: 0s - loss: 0.2052 - vae_kl_loss: 2.2971 - vae_rc_loss: 0.1823
# Epoch 27: vae_rc_loss improved from 0.18254 to 0.18227, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2052 - vae_kl_loss: 2.2971 - vae_rc_loss: 0.1823 - val_loss: 0.2062 - val_vae_kl_loss: 2.2218 - val_vae_rc_loss: 0.1840
# Epoch 28/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2051 - vae_kl_loss: 2.2999 - vae_rc_loss: 0.1821
# Epoch 28: vae_rc_loss improved from 0.18227 to 0.18212, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2051 - vae_kl_loss: 2.2993 - vae_rc_loss: 0.1821 - val_loss: 0.2053 - val_vae_kl_loss: 2.2865 - val_vae_rc_loss: 0.1825
# Epoch 29/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2048 - vae_kl_loss: 2.3102 - vae_rc_loss: 0.1817
# Epoch 29: vae_rc_loss improved from 0.18212 to 0.18172, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2048 - vae_kl_loss: 2.3098 - vae_rc_loss: 0.1817 - val_loss: 0.2058 - val_vae_kl_loss: 2.3650 - val_vae_rc_loss: 0.1821
# Epoch 30/50
# 235/235 [==============================] - ETA: 0s - loss: 0.2047 - vae_kl_loss: 2.3181 - vae_rc_loss: 0.1816
# Epoch 30: vae_rc_loss improved from 0.18172 to 0.18157, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2047 - vae_kl_loss: 2.3181 - vae_rc_loss: 0.1816 - val_loss: 0.2048 - val_vae_kl_loss: 2.2910 - val_vae_rc_loss: 0.1819
# Epoch 31/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2045 - vae_kl_loss: 2.3221 - vae_rc_loss: 0.1813
# Epoch 31: vae_rc_loss improved from 0.18157 to 0.18127, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2045 - vae_kl_loss: 2.3222 - vae_rc_loss: 0.1813 - val_loss: 0.2048 - val_vae_kl_loss: 2.3084 - val_vae_rc_loss: 0.1817
# Epoch 32/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2045 - vae_kl_loss: 2.3247 - vae_rc_loss: 0.1812
# Epoch 32: vae_rc_loss improved from 0.18127 to 0.18120, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2045 - vae_kl_loss: 2.3248 - vae_rc_loss: 0.1812 - val_loss: 0.2051 - val_vae_kl_loss: 2.3436 - val_vae_rc_loss: 0.1816
# Epoch 33/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2044 - vae_kl_loss: 2.3324 - vae_rc_loss: 0.1811
# Epoch 33: vae_rc_loss improved from 0.18120 to 0.18105, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2044 - vae_kl_loss: 2.3313 - vae_rc_loss: 0.1810 - val_loss: 0.2041 - val_vae_kl_loss: 2.3447 - val_vae_rc_loss: 0.1807
# Epoch 34/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2042 - vae_kl_loss: 2.3379 - vae_rc_loss: 0.1808
# Epoch 34: vae_rc_loss improved from 0.18105 to 0.18075, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2041 - vae_kl_loss: 2.3379 - vae_rc_loss: 0.1808 - val_loss: 0.2041 - val_vae_kl_loss: 2.3651 - val_vae_rc_loss: 0.1804
# Epoch 35/50
# 233/235 [============================>.] - ETA: 0s - loss: 0.2040 - vae_kl_loss: 2.3429 - vae_rc_loss: 0.1806
# Epoch 35: vae_rc_loss improved from 0.18075 to 0.18056, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2040 - vae_kl_loss: 2.3429 - vae_rc_loss: 0.1806 - val_loss: 0.2055 - val_vae_kl_loss: 2.3960 - val_vae_rc_loss: 0.1815
# Epoch 36/50
# 235/235 [==============================] - ETA: 0s - loss: 0.2040 - vae_kl_loss: 2.3417 - vae_rc_loss: 0.1805
# Epoch 36: vae_rc_loss improved from 0.18056 to 0.18054, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2040 - vae_kl_loss: 2.3417 - vae_rc_loss: 0.1805 - val_loss: 0.2044 - val_vae_kl_loss: 2.3009 - val_vae_rc_loss: 0.1813
# Epoch 37/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.2038 - vae_kl_loss: 2.3532 - vae_rc_loss: 0.1803
# Epoch 37: vae_rc_loss improved from 0.18054 to 0.18027, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2038 - vae_kl_loss: 2.3530 - vae_rc_loss: 0.1803 - val_loss: 0.2053 - val_vae_kl_loss: 2.2821 - val_vae_rc_loss: 0.1825
# Epoch 38/50
# 233/235 [============================>.] - ETA: 0s - loss: 0.2038 - vae_kl_loss: 2.3516 - vae_rc_loss: 0.1802
# Epoch 38: vae_rc_loss did not improve from 0.18027
# 235/235 [==============================] - 2s 11ms/step - loss: 0.2038 - vae_kl_loss: 2.3517 - vae_rc_loss: 0.1803 - val_loss: 0.2042 - val_vae_kl_loss: 2.3691 - val_vae_rc_loss: 0.1805
# Epoch 39/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2034 - vae_kl_loss: 2.3607 - vae_rc_loss: 0.1798
# Epoch 39: vae_rc_loss improved from 0.18027 to 0.17986, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2035 - vae_kl_loss: 2.3600 - vae_rc_loss: 0.1799 - val_loss: 0.2039 - val_vae_kl_loss: 2.3586 - val_vae_rc_loss: 0.1802
# Epoch 40/50
# 230/235 [============================>.] - ETA: 0s - loss: 0.2033 - vae_kl_loss: 2.3600 - vae_rc_loss: 0.1797
# Epoch 40: vae_rc_loss improved from 0.17986 to 0.17973, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2033 - vae_kl_loss: 2.3588 - vae_rc_loss: 0.1797 - val_loss: 0.2046 - val_vae_kl_loss: 2.3767 - val_vae_rc_loss: 0.1808
# Epoch 41/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2032 - vae_kl_loss: 2.3709 - vae_rc_loss: 0.1795
# Epoch 41: vae_rc_loss improved from 0.17973 to 0.17953, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2032 - vae_kl_loss: 2.3708 - vae_rc_loss: 0.1795 - val_loss: 0.2039 - val_vae_kl_loss: 2.3700 - val_vae_rc_loss: 0.1802
# Epoch 42/50
# 235/235 [==============================] - ETA: 0s - loss: 0.2030 - vae_kl_loss: 2.3701 - vae_rc_loss: 0.1793
# Epoch 42: vae_rc_loss improved from 0.17953 to 0.17930, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2030 - vae_kl_loss: 2.3701 - vae_rc_loss: 0.1793 - val_loss: 0.2038 - val_vae_kl_loss: 2.3279 - val_vae_rc_loss: 0.1805
# Epoch 43/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2030 - vae_kl_loss: 2.3713 - vae_rc_loss: 0.1793
# Epoch 43: vae_rc_loss did not improve from 0.17930
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2030 - vae_kl_loss: 2.3713 - vae_rc_loss: 0.1793 - val_loss: 0.2038 - val_vae_kl_loss: 2.3488 - val_vae_rc_loss: 0.1803
# Epoch 44/50
# 232/235 [============================>.] - ETA: 0s - loss: 0.2030 - vae_kl_loss: 2.3720 - vae_rc_loss: 0.1792
# Epoch 44: vae_rc_loss improved from 0.17930 to 0.17923, saving model to vae.h5
# 235/235 [==============================] - 3s 12ms/step - loss: 0.2030 - vae_kl_loss: 2.3724 - vae_rc_loss: 0.1792 - val_loss: 0.2034 - val_vae_kl_loss: 2.3956 - val_vae_rc_loss: 0.1794
# Epoch 45/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2029 - vae_kl_loss: 2.3773 - vae_rc_loss: 0.1791
# Epoch 45: vae_rc_loss improved from 0.17923 to 0.17913, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2029 - vae_kl_loss: 2.3762 - vae_rc_loss: 0.1791 - val_loss: 0.2034 - val_vae_kl_loss: 2.3305 - val_vae_rc_loss: 0.1801
# Epoch 46/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.2027 - vae_kl_loss: 2.3839 - vae_rc_loss: 0.1789
# Epoch 46: vae_rc_loss improved from 0.17913 to 0.17889, saving model to vae.h5
# 235/235 [==============================] - 3s 12ms/step - loss: 0.2027 - vae_kl_loss: 2.3837 - vae_rc_loss: 0.1789 - val_loss: 0.2036 - val_vae_kl_loss: 2.3030 - val_vae_rc_loss: 0.1806
# Epoch 47/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2027 - vae_kl_loss: 2.3859 - vae_rc_loss: 0.1789
# Epoch 47: vae_rc_loss improved from 0.17889 to 0.17885, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2027 - vae_kl_loss: 2.3858 - vae_rc_loss: 0.1788 - val_loss: 0.2031 - val_vae_kl_loss: 2.3948 - val_vae_rc_loss: 0.1792
# Epoch 48/50
# 233/235 [============================>.] - ETA: 0s - loss: 0.2024 - vae_kl_loss: 2.3951 - vae_rc_loss: 0.1785
# Epoch 48: vae_rc_loss improved from 0.17885 to 0.17847, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2024 - vae_kl_loss: 2.3951 - vae_rc_loss: 0.1785 - val_loss: 0.2031 - val_vae_kl_loss: 2.3864 - val_vae_rc_loss: 0.1792
# Epoch 49/50
# 234/235 [============================>.] - ETA: 0s - loss: 0.2023 - vae_kl_loss: 2.3955 - vae_rc_loss: 0.1784
# Epoch 49: vae_rc_loss improved from 0.17847 to 0.17838, saving model to vae.h5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.2023 - vae_kl_loss: 2.3956 - vae_rc_loss: 0.1784 - val_loss: 0.2039 - val_vae_kl_loss: 2.4134 - val_vae_rc_loss: 0.1797
# Epoch 50/50
# 231/235 [============================>.] - ETA: 0s - loss: 0.2024 - vae_kl_loss: 2.3950 - vae_rc_loss: 0.1784
# Epoch 50: vae_rc_loss did not improve from 0.17838
# 235/235 [==============================] - 3s 10ms/step - loss: 0.2024 - vae_kl_loss: 2.3959 - vae_rc_loss: 0.1784 - val_loss: 0.2033 - val_vae_kl_loss: 2.3797 - val_vae_rc_loss: 0.1795

# %%
vae.load_weights(model_path)
images, labels = next(iter(ds_test_label))
outputs, z_means, z_logvar = vae.encoder(images)
plt.figure(figsize=(8,8))
plt.scatter(outputs[:,0], outputs[:,1], c=labels, cmap='RdYlBu', s=3)
plt.colorbar()

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

@interact
def explore_latent_variable(z1=(-5,5,0.1),
                            z2=(-5,5,0.1)):
    z_samples = np.array([[z1, z2]], dtype=np.float32)
    images = vae.decoder(z_samples)
    plt.figure(figsize=(2,2))
    plt.axis('off')
    plt.imshow(images[0, :, :, 0], cmap='gray')
# Out:
# interactive(children=(FloatSlider(value=0.0, description='z1', max=5.0, min=-5.0), FloatSlider(value=0.0, desc…

# %%
z_samples = np.array([[z1, z2] for z2 in np.arange(-2.5, 2.5, 0.5) for z1 in np.arange(-2.5, 2.5, 0.5)], dtype=np.float32)
images = vae.decoder(z_samples)
grid_col = 10
grid_row = 10

f, axarr = plt.subplots(grid_row, grid_col, figsize=(grid_col, grid_row))

i = 0

for row in range(grid_row):
    for col in range(grid_col):
        axarr[row, col].imshow(images[i,:,:,0], cmap='gray')
        axarr[row, col].axis('off')
        i += 1
plt.show()
