# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Reshape, Conv2DTranspose, MaxPooling2D, UpSampling2D, LeakyReLU
from tensorflow.keras.activations import relu
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import tensorflow_datasets as tfds

import numpy as np
import matplotlib.pyplot as plt

# %%
(ds_train, ds_test_), ds_info = tfds.load('mnist',
                                         split=['test', 'test'],
                                         shuffle_files=True,
                                         as_supervised=True,
                                         with_info=True)

# %%
batch_size = 256

# %%
def preprocess(image, label):
    image = tf.cast(image, tf.float32)
    image = image/255.
    return image, image

# %%
ds_train = ds_train.map(preprocess).cache().shuffle(ds_info.splits['train'].num_examples).batch(batch_size)
ds_test = ds_test_.map(preprocess).batch(batch_size).cache().prefetch(batch_size)

# %%
# return label for testing

def preprocess_with_label(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.math.round(image/255.)
    return image, label

# %%
ds_test_label = ds_test_.map(preprocess_with_label).batch(1000)

# %%
def Encoder(z_dim):
    inputs = layers.Input(shape=[28, 28, 1])
    
    x = inputs
    x = Conv2D(filters=8, kernel_size=(3,3), strides=2, padding='same', activation='relu')(x)
    x = Conv2D(filters=8, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = Conv2D(filters=8, kernel_size=(3,3), strides=2, padding='same', activation='relu')(x)
    x = Conv2D(filters=8, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    
    x = Flatten()(x)
    out = Dense(z_dim)(x)
    
    return Model(inputs=inputs, outputs=out, name='encoder')

# %%
def Decoder(z_dim):
    inputs = layers.Input(shape=[z_dim])
    x = inputs
    x = Dense(7*7*64, activation='relu')(x)
    x = Reshape((7,7,64))(x)
    
    x = Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = UpSampling2D((2,2))(x)
    
    x = Conv2D(filters=32, kernel_size=(3,3), strides=1, padding='same', activation='relu')(x)
    x = UpSampling2D((2,2))(x)
    
    out = Conv2D(filters=1, kernel_size=(3,3), strides=1, padding='same', activation='sigmoid')(x)
    
    #return out
    return Model(inputs=inputs, outputs=out, name='decoder')

# %%
class Autoencoder():
    def __init__(self, z_dim):
        self.encoder = Encoder(z_dim)
        self.decoder = Decoder(z_dim)
        
        model_input = self.encoder.input
        model_output = self.decoder(self.encoder.output)
        self.model = Model(model_input, model_output)

# %%
autoencoder = Autoencoder(z_dim=10)

# %%
autoencoder.encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 14, 14, 8)         80
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         584
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 8)           584
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 8)           584
#
#  flatten (Flatten)           (None, 392)               0
#
#  dense (Dense)               (None, 10)                3930
#
# =================================================================
# Total params: 5,762
# Trainable params: 5,762
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 10)]              0
#
#  dense_1 (Dense)             (None, 3136)              34496
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 64)          36928
#
#  up_sampling2d (UpSampling2D  (None, 14, 14, 64)       0
#  )
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 32)        18464
#
#  up_sampling2d_1 (UpSampling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 90,177
# Trainable params: 90,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_path = 'autoencoder.h5'

# %%
checkpoint = ModelCheckpoint(model_path,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             mode='auto',
                             save_weights_only = False)

early = EarlyStopping(monitor='val_loss',
                      mode='auto',
                      patience=5)

callbacks_list = [checkpoint, early]

# %%
autoencoder.model.compile(
    loss = 'mse',
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=3e-4))
    #metrics=[tf.keras.losses.BianryCrossentropy()])

# %%
autoencoder.model.fit(ds_train, validation_data=ds_test,
                      epochs=100, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 40/40 [==============================] - ETA: 0s - loss: 0.1190
# Epoch 1: val_loss improved from inf to 0.07139, saving model to autoencoder.h5
# 40/40 [==============================] - 5s 36ms/step - loss: 0.1190 - val_loss: 0.0714
# Epoch 2/100
# 40/40 [==============================] - ETA: 0s - loss: 0.0687
# Epoch 2: val_loss improved from 0.07139 to 0.06753, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0687 - val_loss: 0.0675
# Epoch 3/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0652
# Epoch 3: val_loss improved from 0.06753 to 0.06089, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0649 - val_loss: 0.0609
# Epoch 4/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0572
# Epoch 4: val_loss improved from 0.06089 to 0.05659, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0571 - val_loss: 0.0566
# Epoch 5/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0499
# Epoch 5: val_loss improved from 0.05659 to 0.04775, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0499 - val_loss: 0.0478
# Epoch 6/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0459
# Epoch 6: val_loss improved from 0.04775 to 0.04545, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0458 - val_loss: 0.0454
# Epoch 7/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0427
# Epoch 7: val_loss improved from 0.04545 to 0.04062, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0426 - val_loss: 0.0406
# Epoch 8/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0398
# Epoch 8: val_loss improved from 0.04062 to 0.04009, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0398 - val_loss: 0.0401
# Epoch 9/100
# 40/40 [==============================] - ETA: 0s - loss: 0.0379
# Epoch 9: val_loss improved from 0.04009 to 0.03508, saving model to autoencoder.h5
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0379 - val_loss: 0.0351
# Epoch 10/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0359
# Epoch 10: val_loss did not improve from 0.03508
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0358 - val_loss: 0.0352
# Epoch 11/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0343
# Epoch 11: val_loss improved from 0.03508 to 0.03224, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0343 - val_loss: 0.0322
# Epoch 12/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0328
# Epoch 12: val_loss did not improve from 0.03224
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0326 - val_loss: 0.0341
# Epoch 13/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0315
# Epoch 13: val_loss improved from 0.03224 to 0.03001, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0314 - val_loss: 0.0300
# Epoch 14/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0303
# Epoch 14: val_loss did not improve from 0.03001
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0303 - val_loss: 0.0301
# Epoch 15/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0294
# Epoch 15: val_loss improved from 0.03001 to 0.02925, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0294 - val_loss: 0.0293
# Epoch 16/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0285
# Epoch 16: val_loss improved from 0.02925 to 0.02875, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0286 - val_loss: 0.0287
# Epoch 17/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0277
# Epoch 17: val_loss improved from 0.02875 to 0.02743, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0276 - val_loss: 0.0274
# Epoch 18/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0272
# Epoch 18: val_loss improved from 0.02743 to 0.02675, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0272 - val_loss: 0.0268
# Epoch 19/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0266
# Epoch 19: val_loss improved from 0.02675 to 0.02626, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0265 - val_loss: 0.0263
# Epoch 20/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0260
# Epoch 20: val_loss improved from 0.02626 to 0.02463, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0260 - val_loss: 0.0246
# Epoch 21/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0255
# Epoch 21: val_loss improved from 0.02463 to 0.02458, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0255 - val_loss: 0.0246
# Epoch 22/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0250
# Epoch 22: val_loss improved from 0.02458 to 0.02422, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0250 - val_loss: 0.0242
# Epoch 23/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0245
# Epoch 23: val_loss improved from 0.02422 to 0.02413, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0245 - val_loss: 0.0241
# Epoch 24/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0243
# Epoch 24: val_loss improved from 0.02413 to 0.02406, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0242 - val_loss: 0.0241
# Epoch 25/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0239
# Epoch 25: val_loss improved from 0.02406 to 0.02404, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0239 - val_loss: 0.0240
# Epoch 26/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0235
# Epoch 26: val_loss improved from 0.02404 to 0.02293, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0235 - val_loss: 0.0229
# Epoch 27/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0232
# Epoch 27: val_loss did not improve from 0.02293
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0232 - val_loss: 0.0247
# Epoch 28/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0229
# Epoch 28: val_loss improved from 0.02293 to 0.02205, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0229 - val_loss: 0.0221
# Epoch 29/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0226
# Epoch 29: val_loss did not improve from 0.02205
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0226 - val_loss: 0.0228
# Epoch 30/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0223
# Epoch 30: val_loss did not improve from 0.02205
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0224 - val_loss: 0.0234
# Epoch 31/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0221
# Epoch 31: val_loss did not improve from 0.02205
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0221 - val_loss: 0.0230
# Epoch 32/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0219
# Epoch 32: val_loss improved from 0.02205 to 0.02163, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0219 - val_loss: 0.0216
# Epoch 33/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0216
# Epoch 33: val_loss did not improve from 0.02163
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0216 - val_loss: 0.0225
# Epoch 34/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0215
# Epoch 34: val_loss did not improve from 0.02163
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0215 - val_loss: 0.0221
# Epoch 35/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0214
# Epoch 35: val_loss did not improve from 0.02163
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0214 - val_loss: 0.0220
# Epoch 36/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0210
# Epoch 36: val_loss improved from 0.02163 to 0.02111, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0210 - val_loss: 0.0211
# Epoch 37/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0209
# Epoch 37: val_loss did not improve from 0.02111
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0209 - val_loss: 0.0214
# Epoch 38/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0207
# Epoch 38: val_loss improved from 0.02111 to 0.02077, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0207 - val_loss: 0.0208
# Epoch 39/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0205
# Epoch 39: val_loss improved from 0.02077 to 0.02048, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0205 - val_loss: 0.0205
# Epoch 40/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0203
# Epoch 40: val_loss did not improve from 0.02048
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0203 - val_loss: 0.0210
# Epoch 41/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0202
# Epoch 41: val_loss did not improve from 0.02048
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0202 - val_loss: 0.0213
# Epoch 42/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0200
# Epoch 42: val_loss improved from 0.02048 to 0.01993, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0200 - val_loss: 0.0199
# Epoch 43/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0199
# Epoch 43: val_loss did not improve from 0.01993
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0199 - val_loss: 0.0202
# Epoch 44/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0198
# Epoch 44: val_loss improved from 0.01993 to 0.01924, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0198 - val_loss: 0.0192
# Epoch 45/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0197
# Epoch 45: val_loss did not improve from 0.01924
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0197 - val_loss: 0.0200
# Epoch 46/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0195
# Epoch 46: val_loss did not improve from 0.01924
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0195 - val_loss: 0.0197
# Epoch 47/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0193
# Epoch 47: val_loss did not improve from 0.01924
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0193 - val_loss: 0.0202
# Epoch 48/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 48: val_loss did not improve from 0.01924
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0192 - val_loss: 0.0193
# Epoch 49/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0191
# Epoch 49: val_loss improved from 0.01924 to 0.01887, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0192 - val_loss: 0.0189
# Epoch 50/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0190
# Epoch 50: val_loss improved from 0.01887 to 0.01871, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0190 - val_loss: 0.0187
# Epoch 51/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0189
# Epoch 51: val_loss did not improve from 0.01871
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0189 - val_loss: 0.0189
# Epoch 52/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0188
# Epoch 52: val_loss did not improve from 0.01871
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0188 - val_loss: 0.0188
# Epoch 53/100
# 40/40 [==============================] - ETA: 0s - loss: 0.0187
# Epoch 53: val_loss improved from 0.01871 to 0.01814, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0187 - val_loss: 0.0181
# Epoch 54/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0186
# Epoch 54: val_loss did not improve from 0.01814
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0186 - val_loss: 0.0183
# Epoch 55/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0185
# Epoch 55: val_loss improved from 0.01814 to 0.01807, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0185 - val_loss: 0.0181
# Epoch 56/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0183
# Epoch 56: val_loss did not improve from 0.01807
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0183 - val_loss: 0.0187
# Epoch 57/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0183
# Epoch 57: val_loss did not improve from 0.01807
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0183 - val_loss: 0.0182
# Epoch 58/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0181
# Epoch 58: val_loss did not improve from 0.01807
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0181 - val_loss: 0.0190
# Epoch 59/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0181
# Epoch 59: val_loss did not improve from 0.01807
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0181 - val_loss: 0.0204
# Epoch 60/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0180
# Epoch 60: val_loss improved from 0.01807 to 0.01766, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0180 - val_loss: 0.0177
# Epoch 61/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0180
# Epoch 61: val_loss did not improve from 0.01766
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0180 - val_loss: 0.0178
# Epoch 62/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0178
# Epoch 62: val_loss did not improve from 0.01766
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0178 - val_loss: 0.0180
# Epoch 63/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0177
# Epoch 63: val_loss improved from 0.01766 to 0.01749, saving model to autoencoder.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0177 - val_loss: 0.0175
# Epoch 64/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0176
# Epoch 64: val_loss did not improve from 0.01749
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0176 - val_loss: 0.0182
# Epoch 65/100
# 35/40 [=========================>....] - ETA: 0s - loss: 0.0176
# Epoch 65: val_loss did not improve from 0.01749
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 66/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0174
# Epoch 66: val_loss did not improve from 0.01749
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0174 - val_loss: 0.0177
# Epoch 67/100
# 35/40 [=========================>....] - ETA: 0s - loss: 0.0174
# Epoch 67: val_loss did not improve from 0.01749
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0174 - val_loss: 0.0176
# Epoch 68/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0173
# Epoch 68: val_loss did not improve from 0.01749
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0173 - val_loss: 0.0175

# %%
images, labels = next(iter(ds_test))
autoencoder.model = load_model(model_path)
outputs = autoencoder.model.predict(images)
# Out:
# 8/8 [==============================] - 0s 1ms/step

# %%
# Display
grid_col = 10
grid_row = 2

f, axarr = plt.subplots(grid_row, grid_col, figsize=(grid_col*1.1, grid_row))

i = 0
for row in range(0, grid_row, 2):
    for col in range(grid_col):
        axarr[row, col].imshow(images[i,:,:,0], cmap='gray')
        axarr[row, col].axis('off')
        axarr[row+1, col].imshow(outputs[i,:,:,0], cmap='gray')
        axarr[row+1, col].axis('off')
        i+=1
plt.show()

# %%
model_path_2 = 'autoencoder_100.h5'

# %%
autoencoder_100 = Autoencoder(z_dim=100)

# %%
checkpoint = ModelCheckpoint(model_path_2,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             mode='auto',
                             save_weights_only = False)

early = EarlyStopping(monitor='val_loss',
                      mode='auto',
                      patience=5)

callbacks_list = [checkpoint, early]

# %%
autoencoder_100.model.compile(
    loss = 'mse',
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=3e-4))
    #metrics=[tf.keras.losses.BianryCrossentropy()])

# %%
autoencoder_100.model.fit(ds_train, validation_data=ds_test,
                      epochs=100, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.1028
# Epoch 1: val_loss improved from inf to 0.06933, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 16ms/step - loss: 0.1027 - val_loss: 0.0693
# Epoch 2/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0638
# Epoch 2: val_loss improved from 0.06933 to 0.05632, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0640 - val_loss: 0.0563
# Epoch 3/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0506
# Epoch 3: val_loss did not improve from 0.05632
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0502 - val_loss: 0.0605
# Epoch 4/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0407
# Epoch 4: val_loss improved from 0.05632 to 0.03390, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0404 - val_loss: 0.0339
# Epoch 5/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0333
# Epoch 5: val_loss improved from 0.03390 to 0.03236, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0333 - val_loss: 0.0324
# Epoch 6/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0285
# Epoch 6: val_loss improved from 0.03236 to 0.02893, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0282 - val_loss: 0.0289
# Epoch 7/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0248
# Epoch 7: val_loss improved from 0.02893 to 0.02165, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0246 - val_loss: 0.0216
# Epoch 8/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0218
# Epoch 8: val_loss did not improve from 0.02165
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0218 - val_loss: 0.0221
# Epoch 9/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0196
# Epoch 9: val_loss improved from 0.02165 to 0.01781, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0196 - val_loss: 0.0178
# Epoch 10/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0180
# Epoch 10: val_loss improved from 0.01781 to 0.01605, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0180 - val_loss: 0.0161
# Epoch 11/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0167
# Epoch 11: val_loss improved from 0.01605 to 0.01553, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0167 - val_loss: 0.0155
# Epoch 12/100
# 35/40 [=========================>....] - ETA: 0s - loss: 0.0156
# Epoch 12: val_loss improved from 0.01553 to 0.01403, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0155 - val_loss: 0.0140
# Epoch 13/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0146
# Epoch 13: val_loss did not improve from 0.01403
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0146 - val_loss: 0.0143
# Epoch 14/100
# 40/40 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 14: val_loss improved from 0.01403 to 0.01278, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0138 - val_loss: 0.0128
# Epoch 15/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0131
# Epoch 15: val_loss improved from 0.01278 to 0.01169, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0131 - val_loss: 0.0117
# Epoch 16/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0125
# Epoch 16: val_loss improved from 0.01169 to 0.01132, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0124 - val_loss: 0.0113
# Epoch 17/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0120
# Epoch 17: val_loss improved from 0.01132 to 0.01062, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0119 - val_loss: 0.0106
# Epoch 18/100
# 40/40 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 18: val_loss did not improve from 0.01062
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0106
# Epoch 19/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0111
# Epoch 19: val_loss improved from 0.01062 to 0.00961, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0110 - val_loss: 0.0096
# Epoch 20/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 20: val_loss did not improve from 0.00961
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0107 - val_loss: 0.0103
# Epoch 21/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0101
# Epoch 21: val_loss did not improve from 0.00961
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0115
# Epoch 22/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0100
# Epoch 22: val_loss did not improve from 0.00961
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0100 - val_loss: 0.0104
# Epoch 23/100
# 40/40 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 23: val_loss improved from 0.00961 to 0.00915, saving model to autoencoder_100.h5
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0097 - val_loss: 0.0092
# Epoch 24/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0093
# Epoch 24: val_loss did not improve from 0.00915
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0093 - val_loss: 0.0105
# Epoch 25/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0091
# Epoch 25: val_loss improved from 0.00915 to 0.00853, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0091 - val_loss: 0.0085
# Epoch 26/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0089
# Epoch 26: val_loss did not improve from 0.00853
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0089 - val_loss: 0.0101
# Epoch 27/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0086
# Epoch 27: val_loss did not improve from 0.00853
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 28/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0084
# Epoch 28: val_loss improved from 0.00853 to 0.00815, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0084 - val_loss: 0.0082
# Epoch 29/100
# 35/40 [=========================>....] - ETA: 0s - loss: 0.0083
# Epoch 29: val_loss improved from 0.00815 to 0.00752, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0082 - val_loss: 0.0075
# Epoch 30/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0081
# Epoch 30: val_loss did not improve from 0.00752
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 31/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0080
# Epoch 31: val_loss did not improve from 0.00752
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0079 - val_loss: 0.0081
# Epoch 32/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0078
# Epoch 32: val_loss improved from 0.00752 to 0.00726, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0078 - val_loss: 0.0073
# Epoch 33/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0077
# Epoch 33: val_loss improved from 0.00726 to 0.00718, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0077 - val_loss: 0.0072
# Epoch 34/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0074
# Epoch 34: val_loss did not improve from 0.00718
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 35/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0073
# Epoch 35: val_loss did not improve from 0.00718
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 36/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 36: val_loss did not improve from 0.00718
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0072 - val_loss: 0.0074
# Epoch 37/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0071
# Epoch 37: val_loss improved from 0.00718 to 0.00666, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0071 - val_loss: 0.0067
# Epoch 38/100
# 40/40 [==============================] - ETA: 0s - loss: 0.0070
# Epoch 38: val_loss did not improve from 0.00666
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 39/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0068
# Epoch 39: val_loss improved from 0.00666 to 0.00625, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 40/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0067
# Epoch 40: val_loss did not improve from 0.00625
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0074
# Epoch 41/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0067
# Epoch 41: val_loss did not improve from 0.00625
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0066 - val_loss: 0.0073
# Epoch 42/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0065
# Epoch 42: val_loss did not improve from 0.00625
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 43/100
# 37/40 [==========================>...] - ETA: 0s - loss: 0.0064
# Epoch 43: val_loss did not improve from 0.00625
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0065 - val_loss: 0.0075
# Epoch 44/100
# 35/40 [=========================>....] - ETA: 0s - loss: 0.0063
# Epoch 44: val_loss improved from 0.00625 to 0.00611, saving model to autoencoder_100.h5
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 45/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 45: val_loss did not improve from 0.00611
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0065
# Epoch 46/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0062
# Epoch 46: val_loss did not improve from 0.00611
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0062 - val_loss: 0.0071
# Epoch 47/100
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0061
# Epoch 47: val_loss did not improve from 0.00611
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 48/100
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0060
# Epoch 48: val_loss did not improve from 0.00611
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 49/100
# 39/40 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 49: val_loss did not improve from 0.00611
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0059 - val_loss: 0.0073

# %%
images, labels = next(iter(ds_test))
autoencoder_100.model = load_model(model_path_2)
outputs = autoencoder_100.model.predict(images)
# Out:
# 8/8 [==============================] - 0s 2ms/step

# %%
# Display
grid_col = 10
grid_row = 2

f, axarr = plt.subplots(grid_row, grid_col, figsize=(grid_col*1.1, grid_row))

i = 0
for row in range(0, grid_row, 2):
    for col in range(grid_col):
        axarr[row, col].imshow(images[i,:,:,0], cmap='gray')
        axarr[row, col].axis('off')
        axarr[row+1, col].imshow(outputs[i,:,:,0], cmap='gray')
        axarr[row+1, col].axis('off')
        i+=1
plt.show()

# %%
autoencoder_2 = Autoencoder(z_dim=2)

early = EarlyStopping(monitor='val_loss',
                      mode='auto',
                      patience=5)

callbacks_list = [early]

autoencoder_2.model.compile(
    loss='mse',
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-3))

autoencoder_2.model.fit(ds_train, validation_data=ds_test,
                        epochs = 50, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0934 - val_loss: 0.0747
# Epoch 2/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0647 - val_loss: 0.0620
# Epoch 3/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0589 - val_loss: 0.0567
# Epoch 4/50
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0562 - val_loss: 0.0540
# Epoch 5/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0544 - val_loss: 0.0532
# Epoch 6/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0531 - val_loss: 0.0530
# Epoch 7/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0524 - val_loss: 0.0521
# Epoch 8/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0517 - val_loss: 0.0545
# Epoch 9/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0512 - val_loss: 0.0522
# Epoch 10/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0506 - val_loss: 0.0535
# Epoch 11/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0503 - val_loss: 0.0495
# Epoch 12/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0498 - val_loss: 0.0498
# Epoch 13/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0494 - val_loss: 0.0496
# Epoch 14/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0489 - val_loss: 0.0494
# Epoch 15/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0487 - val_loss: 0.0483
# Epoch 16/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0480 - val_loss: 0.0493
# Epoch 17/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0479 - val_loss: 0.0498
# Epoch 18/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0477 - val_loss: 0.0474
# Epoch 19/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0473 - val_loss: 0.0486
# Epoch 20/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0471 - val_loss: 0.0475
# Epoch 21/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0466 - val_loss: 0.0481
# Epoch 22/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0465 - val_loss: 0.0474
# Epoch 23/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0463 - val_loss: 0.0472
# Epoch 24/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0462 - val_loss: 0.0469
# Epoch 25/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0459 - val_loss: 0.0463
# Epoch 26/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0458 - val_loss: 0.0473
# Epoch 27/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0457 - val_loss: 0.0480
# Epoch 28/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0454 - val_loss: 0.0457
# Epoch 29/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0453 - val_loss: 0.0469
# Epoch 30/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0452 - val_loss: 0.0488
# Epoch 31/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0452 - val_loss: 0.0460
# Epoch 32/50
# 40/40 [==============================] - 1s 12ms/step - loss: 0.0450 - val_loss: 0.0456
# Epoch 33/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0448 - val_loss: 0.0460
# Epoch 34/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0448 - val_loss: 0.0458
# Epoch 35/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0447 - val_loss: 0.0448
# Epoch 36/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0445 - val_loss: 0.0461
# Epoch 37/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0444 - val_loss: 0.0449
# Epoch 38/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0444 - val_loss: 0.0462
# Epoch 39/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0443 - val_loss: 0.0455
# Epoch 40/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0442 - val_loss: 0.0444
# Epoch 41/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0440 - val_loss: 0.0471
# Epoch 42/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0441 - val_loss: 0.0462
# Epoch 43/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0439 - val_loss: 0.0480
# Epoch 44/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0439 - val_loss: 0.0455
# Epoch 45/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0438 - val_loss: 0.0447

# %%
images, labels = next(iter(ds_test_label))
outputs = autoencoder_2.encoder.predict(images)
plt.figure(figsize=(8,8))
plt.scatter(outputs[:,0], outputs[:,1], c=labels, cmap='RdYlBu', s=3)
plt.colorbar()
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %%
z_samples = np.array([[z1, z2] for z2 in np.arange(-5, 5, 1.) for z1 in np.arange(-5, 5, 1.)])
images = autoencoder_2.decoder.predict(z_samples)
grid_col = 10
grid_row = 10

f, axarr = plt.subplots(grid_row, grid_col, figsize=(grid_col, grid_row))

i=0
for row in range(grid_row):
    for col in range(grid_col):
        axarr[row, col].imshow(images[i,:,:,0], cmap='gray')
        axarr[row, col].axis('off')
        i += 1
plt.show()
# Out:
# 4/4 [==============================] - 0s 50ms/step

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
@interact
def explore_latent_variable(z1 = (-5,5,0.1),
                            z2 = (-5,5,0.1)):
    z_samples = [[z1, z2]]
    images = autoencoder_2.decoder.predict(z_samples)
    plt.figure(figsize=(2,2))
    plt.imshow(images[0,:,:,0], cmap='gray')
# Out:
# interactive(children=(FloatSlider(value=0.0, description='z1', max=5.0, min=-5.0), FloatSlider(value=0.0, desc…
