# %%
import numpy as np

num_samples_per_class = 1000

negative_samples = np.random.multivariate_normal(
    mean = [0, 3],
    cov = [[1, 0.5], [0.5, 1]],
    size = num_samples_per_class)\

positive_samples = np.random.multivariate_normal(
    mean = [3, 0],
    cov = [[1, 0.5], [0.5, 1]],
    size = num_samples_per_class)

# %%
inputs = np.vstack((negative_samples, positive_samples)).astype(np.float32)

# %%
targets = np.vstack((np.zeros((num_samples_per_class, 1), dtype='float32'),
                     np.ones((num_samples_per_class, 1), dtype='float32')))

# %%
inputs
# Out:
# array([[ 0.5256057 ,  2.929693  ],
#        [-1.5339171 ,  1.9813999 ],
#        [ 2.9409328 ,  3.8016346 ],
#        ...,
#        [ 4.889796  ,  1.5704978 ],
#        [ 2.2011185 ,  0.22814809],
#        [ 2.988631  ,  0.18241355]], dtype=float32)

# %%
targets
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(inputs[:,0], inputs[:,1], c=targets[:,0])
plt.show()

# %%
input_dim = 2
output_dim = 1

# %%
import tensorflow as tf

W = tf.Variable(initial_value=tf.random.uniform(shape=(input_dim, output_dim)))
b = tf.Variable(initial_value=tf.zeros(shape=(output_dim,)))

# %%
W
# Out:
# <tf.Variable 'Variable:0' shape=(2, 1) dtype=float32, numpy=
# array([[0.42826068],
#        [0.41360378]], dtype=float32)>

# %%
b
# Out:
# <tf.Variable 'Variable:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>

# %%
def model(inputs):
    return tf.matmul(inputs, W) + b

# %%
def square_loss(targets, predictions):
    per_sample_losses = tf.square(targets - predictions)
    return tf.reduce_mean(per_sample_losses)

# %%
learning_rate = 0.1

def training_step(inputs, targets):
    with tf.GradientTape() as tape:
        predictions = model(inputs)
        loss = square_loss(predictions, targets)
    grad_loss_wrt_W, grad_loss_wrt_b = tape.gradient(loss, [W, b])
    W.assign_sub(grad_loss_wrt_W * learning_rate)
    b.assign_sub(grad_loss_wrt_b * learning_rate)
    return loss

# %%
for step in range(40):
    loss = training_step(inputs, targets)
    print(f"loss at step {step}: {loss:.4f}")
# Out:
# loss at step 0: 1.3654
# loss at step 1: 0.2702
# loss at step 2: 0.1363
# loss at step 3: 0.1106
# loss at step 4: 0.1007
# loss at step 5: 0.0936
# loss at step 6: 0.0875
# loss at step 7: 0.0820
# loss at step 8: 0.0769
# loss at step 9: 0.0723
# loss at step 10: 0.0681
# loss at step 11: 0.0644
# loss at step 12: 0.0609
# loss at step 13: 0.0578
# loss at step 14: 0.0549
# loss at step 15: 0.0523
# loss at step 16: 0.0499
# loss at step 17: 0.0478
# loss at step 18: 0.0458
# loss at step 19: 0.0441
# loss at step 20: 0.0424
# loss at step 21: 0.0410
# loss at step 22: 0.0396
# loss at step 23: 0.0384
# loss at step 24: 0.0373
# loss at step 25: 0.0363
# loss at step 26: 0.0354
# loss at step 27: 0.0345
# loss at step 28: 0.0338
# loss at step 29: 0.0331
# loss at step 30: 0.0325
# loss at step 31: 0.0319
# loss at step 32: 0.0314
# loss at step 33: 0.0309
# loss at step 34: 0.0305
# loss at step 35: 0.0301
# loss at step 36: 0.0297
# loss at step 37: 0.0294
# loss at step 38: 0.0291
# loss at step 39: 0.0289

# %%
predictions = model(inputs)

# %%
plt.scatter(inputs[:, 0], inputs[:, 1], c=predictions[:, 0] > 0.5)
plt.show()

# %%
x = np.linspace(-1, 4, 100)
y = - W[0] / W[1] * x + (0.5 - b) / W[1]

# %%
plt.plot(x, y, '-r')
plt.scatter(inputs[:,0], inputs[:, 1], c=predictions[:,0]>0.5)
